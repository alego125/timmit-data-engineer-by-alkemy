# %% [markdown]
# **Antes de realizar las instalaciones debemos activar el kernel con el entorno virtual como explica la documentacion del readme**
#
# **1) Instalar Pandas en Jupyter Notebook**

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Importamos pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **2) Cargar un data frame desde un archivo csv**

# %% [markdown]
# ##### Dataframes utilizados
# ---
# 1) [Dataset juicios por brujeria (CSV)](https://www.kaggle.com/datasets/michaelbryantds/witch-trials)
#
# 2) [Factores de muerte al rededor del mundo (XLSX)](https://www.kaggle.com/datasets/adriandiazny/world-wide-death-factors)

# %%
dfCsv = pd.read_csv(r'trials.csv')

# %% [markdown]
# **3) Cargar un data frame distinto desde un archivo Excel**

# %%
dfExcel = pd.read_excel(r'death_risk.xlsx')

# %%
# Elimino los espacios delante y atras de los nombre de las columnas para que no genern problemas mas adelante
newColumns = [column.strip() for column in dfExcel.columns]
dfExcel.columns = newColumns

# %% [markdown]
# 4) Mostrar los datos de ambos dataframes

# %% [markdown]
# dfCsv

# %%
dfCsv.sample(5)
# Out:
#         year  decade  century  tried  deaths     city         gadm.adm2  \
# 2454  1314.0    1310     1300      1     1.0      NaN               NaN
# 3562  1629.0    1620     1600      1     0.0      NaN  Scottish Borders
# 2395  1586.0    1580     1500      1     1.0    Paris             Paris
# 8326  1565.0    1560     1500      1     0.0   Geneva            Geneve
# 700   1585.0    1580     1500      1     NaN  Aichach     Mittelfranken
#
#           gadm.adm1       gadm.adm0        lon        lat  \
# 2454            NaN          France        NaN        NaN
# 3562       Scotland  United Kingdom        NaN        NaN
# 2395  Ile-de-France          France   2.352222  48.856614
# 8326         Geneve     Switzerland   6.142300  46.198400
# 700          Bayern         Germany  11.136000  48.457700
#
#               record.source
# 2454         Carlson (2004)
# 3562  Goodare et al. (2003)
# 2395         Carlson (2004)
# 8326          Monter (1976)
# 700        Behringer (1987)

# %%
dfCsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10940 entries, 0 to 10939
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           10009 non-null  float64
#  1   decade         10940 non-null  int64
#  2   century        10940 non-null  int64
#  3   tried          10940 non-null  int64
#  4   deaths         7114 non-null   float64
#  5   city           5727 non-null   object
#  6   gadm.adm2      9893 non-null   object
#  7   gadm.adm1      10781 non-null  object
#  8   gadm.adm0      10940 non-null  object
#  9   lon            5137 non-null   float64
#  10  lat            5137 non-null   float64
#  11  record.source  10940 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 1.0+ MB

# %% [markdown]
# dfExcel

# %%
dfExcel.sample(5)
# Out:
#              Entity  Year  Outdoor air pollution  \
# 550         Belgium  2000                   5755
# 458      Bangladesh  1998                  30768
# 4514      Palestine  2004                   1346
# 6333  United States  1993                 104872
# 273         Armenia  1993                   2690
#
#       High systolic blood pressure  Diet high in sodium  \
# 550                          18794                 2288
# 458                          69883                 6418
# 4514                          2789                  106
# 6333                        510254                32627
# 273                           7292                 1389
#
#       Diet low in whole grains  Alcohol use  Diet low in fruits  \
# 550                       3764         6905                1629
# 458                       6427         6407               15849
# 4514                       793          160                 248
# 6333                    104014        76507               41879
# ...

# %%
dfExcel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 30 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Entity                                         6840 non-null   object
#  1   Year                                           6840 non-null   int64
#  2   Outdoor air pollution                          6840 non-null   int64
#  3   High systolic blood pressure                   6840 non-null   int64
#  4   Diet high in sodium                            6840 non-null   int64
#  5   Diet low in whole grains                       6840 non-null   int64
#  6   Alcohol use                                    6840 non-null   int64
#  7   Diet low in fruits                             6840 non-null   int64
#  8   Unsafe water source                            6840 non-null   int64
# ...

# %% [markdown]
# ### Extra

# %% [markdown]
# --------

# %% [markdown]
# Eliminamos las filas que contengan valores nulos

# %%
dfCsvWithoutNaN = dfCsv.dropna(axis=0, how="any", thresh=None, subset=None, inplace=False)
dfCsvWithoutNaN
# Out:
#          year  decade  century  tried  deaths        city        gadm.adm2  \
# 541    1590.0    1590     1500      6     6.0   Erolzheim         Freiburg
# 561    1435.0    1430     1400      1     1.0   Straubing    Mittelfranken
# 564    1445.0    1440     1400      2     2.0      Lindau    Mittelfranken
# 570    1467.0    1460     1400      1     1.0  Regensburg    Mittelfranken
# 573    1466.0    1460     1400      2     0.0      Aschau    Mittelfranken
# ...       ...     ...      ...    ...     ...         ...              ...
# 10641  1643.0    1640     1600      1     0.0      Bruges  West-Vlaanderen
# 10642  1643.0    1640     1600      1     0.0      Bruges  West-Vlaanderen
# 10643  1649.0    1640     1600      1     0.0      Bruges  West-Vlaanderen
# 10644  1654.0    1650     1600      1     1.0      Bruges  West-Vlaanderen
# 10645  1657.0    1650     1600      1     0.0      Bruges  West-Vlaanderen
#
# ...

# %% [markdown]
# ----------

# %% [markdown]
# **5) Instalar matplotlib**

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# **6) Realizar las siguientes acciones sobre el segundo dataframe:**
#   * **Group By sobre un campo y utilizando sum()**
#   * **Realizar un Melt**

# %%
# Juicios por brujeria por siglo
triedByCentury = dfCsv.groupby(['century'])[['tried']].sum()
triedByCentury.reset_index(inplace=True)
triedByCentury
# Out:
#    century  tried
# 0     1300    423
# 1     1400   2560
# 2     1500   8951
# 3     1600  28788
# 4     1700   2515
# 5     1800      3

# %%
dfToMelt = dfExcel[['Year','Entity','Outdoor air pollution']].dropna(axis=0, how="any", thresh=None, subset=None, inplace=False)
dfToMelt
# Out:
#       Year       Entity  Outdoor air pollution
# 0     1990  Afghanistan                   3169
# 1     1991  Afghanistan                   3222
# 2     1992  Afghanistan                   3395
# 3     1993  Afghanistan                   3623
# 4     1994  Afghanistan                   3788
# ...    ...          ...                    ...
# 6835  2015     Zimbabwe                   2835
# 6836  2016     Zimbabwe                   2781
# 6837  2017     Zimbabwe                   2700
# 6838  2018     Zimbabwe                   2669
# 6839  2019     Zimbabwe                   2680
#
# [6840 rows x 3 columns]

# %%
# Traspuesta
dfToMelt.melt()
# Out:
#                     variable value
# 0                       Year  1990
# 1                       Year  1991
# 2                       Year  1992
# 3                       Year  1993
# 4                       Year  1994
# ...                      ...   ...
# 20515  Outdoor air pollution  2835
# 20516  Outdoor air pollution  2781
# 20517  Outdoor air pollution  2700
# 20518  Outdoor air pollution  2669
# 20519  Outdoor air pollution  2680
#
# [20520 rows x 2 columns]

# %%
dfExcel
# Out:
#            Entity  Year  Outdoor air pollution  High systolic blood pressure  \
# 0     Afghanistan  1990                   3169                         25633
# 1     Afghanistan  1991                   3222                         25872
# 2     Afghanistan  1992                   3395                         26309
# 3     Afghanistan  1993                   3623                         26961
# 4     Afghanistan  1994                   3788                         27658
# ...           ...   ...                    ...                           ...
# 6835     Zimbabwe  2015                   2835                         11483
# 6836     Zimbabwe  2016                   2781                         11663
# 6837     Zimbabwe  2017                   2700                         11819
# 6838     Zimbabwe  2018                   2669                         12002
# 6839     Zimbabwe  2019                   2680                         12241
#
# ...

# %%
# Muertes por abuso de alcohol por año
dfAlcoholUse = dfExcel.groupby(['Year'])[['Alcohol use']].sum()
dfAlcoholUse.reset_index(inplace=True)
dfAlcoholUse
# Out:
#     Year  Alcohol use
# 0   1990      9955320
# 1   1991     10162920
# 2   1992     10434867
# 3   1993     10808323
# 4   1994     11121347
# 5   1995     11261721
# 6   1996     11277192
# 7   1997     11307562
# 8   1998     11417094
# 9   1999     11658155
# 10  2000     11907468
# 11  2001     12099723
# 12  2002     12398426
# 13  2003     12667915
# 14  2004     12829338
# 15  2005     13103845
# 16  2006     13020871
# 17  2007     13091539
# 18  2008     13345106
# 19  2009     13317518
# 20  2010     13461277
# 21  2011     13379703
# 22  2012     13445325
# 23  2013     13502753
# 24  2014     13571968
# 25  2015     13761413
# 26  2016     13926210
# 27  2017     14061594
# 28  2018     14287938
# 29  2019     14580012

# %%
dfDeaths = dfCsv.groupby(['city'], as_index=False)[['deaths','tried']].sum()
dfDeaths = dfDeaths[dfDeaths['deaths'] > 100 ]
dfDeaths
# Out:
#                      city  deaths  tried
# 33               Arnsberg   152.0    220
# 54        Bad Mergentheim   139.0    165
# 65            Baden-Baden   123.0    124
# 69                  Balve   307.0    323
# 241             Ellwangen   396.0    401
# 281              Freising   102.0    144
# 504         Marktoberdorf   109.0    114
# 547              Morhange   102.0    126
# 617          Ortenaukreis   105.0    111
# 700  Rottenburg am Neckar   148.0    156
# 886              Wurzburg   219.0    219

# %%
# Muertes por siglo de enjuiciados por brujeria
dfDeathsByCentury = dfCsv.groupby('century', as_index=False)[['deaths']].sum()
dfDeathsByCentury.plot(x='century', y='deaths', kind='bar')
plt.show()

# %% [markdown]
# **7) Realizar un gráfico de Barras con el primer dataframe**

# %%
triedByCentury.plot(x='century', y='tried', kind = 'line')

plt.show()

# %%
dfAlcoholUse.plot(x='Year', y='Alcohol use', kind = 'bar')

plt.show()

# %% [markdown]
# ### Analisis extra de otro dataframe
# ---

# %%
dfCowEmision = pd.read_csv(r'emisiones_ganado.csv', sep=";")
dfCowEmision.columns = ['año','emision', 'unidad']
dfCowEmision.sample(5)
# Out:
#      año  emision           unidad
# 17  2007     1.41  tCO2eq / Cabeza
# 8   1998     1.59  tCO2eq / Cabeza
# 15  2005     1.47  tCO2eq / Cabeza
# 9   1999     1.62  tCO2eq / Cabeza
# 2   1992     1.57  tCO2eq / Cabeza

# %%
dfCowEmision.plot(x='año', y='emision', kind='line')
plt.show()
